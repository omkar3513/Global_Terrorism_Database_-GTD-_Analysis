# %% [markdown]
# <a href="https://colab.research.google.com/github/omkar3513/Global_Terrorism_Database_-GTD-_Analysis/blob/main/Copy_of_Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %% [markdown]
# The dataset Includes information on terrorist attacks around the world from 1970 to 2017. It contains more than 180000 terrorist attacks.
#
#
#
#
# ![1_--lSYcmOyzPnRAfhVO3DEg.png](data:image/png;base64,...)

# %% [markdown]
# The Global Terrorism Database (GTD) documents more than 200,000 international and domestic terrorist attacks that occurred worldwide since 1970. An action must also be carried out for political, economic, religious, or social purposes to count as terrorism. The GTD defined as: "The unlawful use of force or violence against persons or property to intimidate or coerce a Government, the civilian population, or any segment thereof, in furtherance of political or social objectives." The GTD includes more than 83,000 bombings . It also includes more than 18000 assassinations and more than 11000 kidnappings.

# %% [markdown]
# **1)** **year** **Vs** **Number** **of** **terrorist attack?**
#
# **2)** **which** **top** **5 countries** **has** **highest** **terrorist attacks?**
#
# **3) which** **5 cities has** **hightest terrorist** **attacks?**
#
# **4) which attack** **types mostly used?**
#
# **5) which regions** **has hightest** **terrorist attacks?**
#
# **6) which weapon** **is mostly used** **by terrorist?**
#
# **7) find motive** **behind the  terrorist** **attacks?**
#
# **8) who are main targets of attacks?**
#
# **9) which groups are mostly active terrorist attacks?**

# %% [markdown]
# **import libraries and datasets.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
file_path ='/content/drive/MyDrive/datasets/Global_Terrorism_Data.csv'
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv(file_path,encoding = 'ISO-8859-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# The purpose of encoding is to transform data so that it can be properly (and safely) consumed by a different type of system. The goal is not to keep information secret, but rather to ensure that it's able to be properly consumed.

# %%
# To see what types of data we are dealing with and how much data we have.
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# shape of dataset
data.shape
# Out:
# (181691, 135)

# %% [markdown]
# From the shape dataset have 181691 rows and 135 columns.

# %%
data.head(5)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
#information about each column in dataset.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
#statistical analysis
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# checking the missing values
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# percentage of missing values per column

# %%
high_missing_values = data.isnull().sum().sort_values(ascending = False)/ len(data)*100

# %%
high_missing_values[high_missing_values != 0]
# Out:
# gsubname3           99.988992
# weapsubtype4_txt    99.961473
# weapsubtype4        99.961473
# weaptype4           99.959822
# weaptype4_txt       99.959822
#                       ...
# guncertain1          0.209146
# ishostkid            0.097969
# specificity          0.003302
# doubtterr            0.000550
# multiple             0.000550
# Length: 106, dtype: float64

# %% [markdown]
# Here we can see lots of variables have more than 99 percent data has missing, so : Theoretically, 25 to 30% maximum missing values are allowed, beyond which we might want to drop the variable from analysis. Practically totally depends upon the importance of the variable.

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation = 90 )
high_missing_values[high_missing_values != 0].plot(kind = 'bar')

# %%
len(high_missing_values[high_missing_values >40])
# Out:
# 77

# %% [markdown]
# In the dataset 77 those variable have more than 40 percent missing values.

# %% [markdown]
# ##Exploratory data analysis
#
# Start Exploratory Data analysis using these columns.

# %%
# renaming cloumns

# %%
data.rename(columns= {'iyear':'Year','imonth':'Month','country_txt':'Country','region_txt': 'Region','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','gname':'Group','provstate':'State','city':'City','motive':'Motive','nwound':'wound','nkill':'killed'}, inplace = True)

# %%
#extract requried columns for analysis
df= data[['Year','Month','Country','Region','City','Attack_type','Target_type','Weapon_type','Group','Motive','State','killed','wound']]

# %%
df.shape
# Out:
# (181691, 13)

# %%
df.head()
# Out:
#    Year  Month             Country                       Region  \
# 0  1970      7  Dominican Republic  Central America & Caribbean
# 1  1970      0              Mexico                North America
# 2  1970      1         Philippines               Southeast Asia
# 3  1970      1              Greece               Western Europe
# 4  1970      1               Japan                    East Asia
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
#   Weapon_type                               Group Motive    State  killed  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Country      181691 non-null  object
#  3   Region       181691 non-null  object
#  4   City         181257 non-null  object
#  5   Attack_type  181691 non-null  object
#  6   Target_type  181691 non-null  object
#  7   Weapon_type  181691 non-null  object
#  8   Group        181691 non-null  object
#  9   Motive       50561 non-null   object
#  10  State        181270 non-null  object
#  11  killed       171378 non-null  float64
#  12  wound        165380 non-null  float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 18.0+ MB

# %%
df.isnull().sum()
# Out:
# Year                0
# Month               0
# Country             0
# Region              0
# City              434
# Attack_type         0
# Target_type         0
# Weapon_type         0
# Group               0
# Motive         131130
# State             421
# killed          10313
# wound           16311
# dtype: int64

# %% [markdown]
# Handling with missing values

# %%
df['City'].fillna(value='Unknown',inplace= True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Motive'].fillna(value='Unknown',inplace= True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['State'].fillna(value='Unknown',inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Country            0
# Region             0
# City               0
# Attack_type        0
# Target_type        0
# Weapon_type        0
# Group              0
# Motive             0
# State              0
# killed         10313
# wound          16311
# dtype: int64

# %% [markdown]
# As our data is handled, we now move on to the exploration of the data.

# %%
a= df.corr()
plt.figure(figsize= (15,15))
sns.heatmap(a,annot= True, annot_kws= {'size':10}, linewidths = 1, vmin = 0, vmax=0.6,cmap= 'ocean_r')
plt.title('correaltion matrix')
plt.show()

# %% [markdown]
# 1) year Vs Number of terrorist attack?

# %%
y= data['Year'].value_counts()
year_counts=pd.DataFrame(y)
year_plot =year_counts.reset_index()
year_plot.head()
# Out:
#    index   Year
# 0   2014  16903
# 1   2015  14965
# 2   2016  13587
# 3   2013  12036
# 4   2017  10900

# %%
year_plot.rename(columns= {'index': 'year','Year':'total_incidents'}, inplace = True)
year_plot.head()
# Out:
#    year  total_incidents
# 0  2014            16903
# 1  2015            14965
# 2  2016            13587
# 3  2013            12036
# 4  2017            10900

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation = 45)
sns.lineplot(x= 'year',  y = 'total_incidents',data = year_plot)
plt.title('Number of attacks in each year')
# Out:
# Text(0.5, 1.0, 'Number of attacks in each year')

# %% [markdown]
# 1. The terrorist attacks gradual increase in 2004.
# 2. The highest peak of attacks in 2014.
# 3. After 2014 attacks decreases.

# %% [markdown]
# 2) which top 5 countries has highest terrorist attacks?

# %%
from matplotlib import figure
plt.figure(figsize=(20,8))
plt.xticks(rotation = 40)
sns.barplot(df['Country'].value_counts()[0:20].index,df['Country'].value_counts()[0:20].values)
plt.title('countries having terrorist attack')
plt.xlabel('country')
plt.ylabel('frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'frequency')

# %% [markdown]
# Iraq, Pakistan, Afghanistan, India and Colombia these countries has highest terrorist attacks.

# %% [markdown]
# 3) which 5 cities has hightest terrorist attacks?

# %%
df['City'].value_counts().head(6)
# Out:
# Unknown    10209
# Baghdad     7589
# Karachi     2652
# Lima        2359
# Mosul       2265
# Belfast     2171
# Name: City, dtype: int64

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation= 40)
sns.barplot(df['City'].value_counts()[1:10].index, df['City'].value_counts()[1:10].values)
plt.title('cities having terrorist attack')
plt.xlabel('cities')
plt.ylabel('frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'frequency')

# %% [markdown]
# Baghdad, Karachi, Lima, Mosul, Belfast this cities has highest terrorist attack.

# %% [markdown]
# 4) which attack types mostly used?

# %%
df['Attack_type'].value_counts().head(10) #heat map
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_type, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation = 40)
plt.title('Number of attacks in each year')
sns.barplot(df['Attack_type'].value_counts().index,df['Attack_type'].value_counts()[0:10].values)
plt.xlabel('Weapons')
plt.ylabel('frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'frequency')

# %% [markdown]
# Bombing/Explosion, Armed Assault these attack types are mostly used.

# %% [markdown]
# Number of Bombing per year

# %%
b_group = df.groupby(['Attack_type'])
bombing= b_group.get_group('Bombing/Explosion')

# %%
q= bombing['Year'].value_counts()
bomb_atk_counts=pd.DataFrame(q)
bomb_atk_counts
bomb_atk_counts =bomb_atk_counts.reset_index()
bomb_atk_counts.head()
#here we can reset the column names
bomb_atk_counts.rename(columns= {'index': 'year','Year':'toatl_incident'}, inplace = True)
bomb_atk_counts.head()

plt.figure(figsize=(20,8))
plt.xticks(rotation = 45)
sns.lineplot(x= 'year', y= 'toatl_incident' , data = bomb_atk_counts)
plt.title('Number of bombing per year')
# Out:
# Text(0.5, 1.0, 'Number of bombing per year')

# %% [markdown]
# Bombing/Explosion mostly used.
# 1. The Bombing/Explosion gradual increase in 2004 till 2014
# 2. After 2014 attacks decreases.

# %% [markdown]
# 5) which regions has hightest terrorist attacks?

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation = 60)
sns.barplot(df['Region'].value_counts().index,df['Region'].value_counts().values)
plt.title('regions having terrorist attack')
plt.xlabel('Region')
plt.ylabel('frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'frequency')

# %% [markdown]
# Terrorist Activities in each Year w.r.t region

# %%
pd.crosstab(df['Year'], df['Region']).plot(kind='area',figsize=(15,6))
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# 1. From barplot and cross tab we can see that Middle East & North Africa, South Africa are highest terrorist attack region.
# 2. Australia and Oceania and Central America has maximum attack after 2004.
# 3. There have been less terrorist attack in East Asia and north America.

# %% [markdown]
# Attacks in details.

# %%
df['casualities'] = df['wound']+ df['killed']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from scipy import signal
import plotly.express as px

# %%
graph = px.treemap(df, values='casualities', path=['Region','Target_type'],
                   color_discrete_sequence= px.colors.qualitative.Dark24,
                   title= 'Deatils of groups being attacked')
graph.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 6) which weapon is mostly used by terrorist?

# %%
df['Weapon_type'].value_counts()
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation = 60)
sns.barplot(df['Weapon_type'].value_counts()[0:].index,df['Weapon_type'].value_counts()[0:].values)
plt.title('Weapons are used terrorist attack')
plt.xlabel('Weapons')
plt.ylabel('frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'frequency')

# %% [markdown]
# Explosion and Firearms are mostly used for terrorist attcks.

# %% [markdown]
# 7) find motive behind the terrorist attacks?

# %%
attack_motive = (df[df['Motive']!= 'Unknown'])
attack_motive['Motive']
# Out:
# 5            To protest the Cairo Illinois Police Deparment
# 8               To protest the War in Vietnam and the draft
# 9               To protest the War in Vietnam and the draft
# 11                        Protest the draft and Vietnam War
# 14        To protest United States owned businesses in P...
#                                 ...
# 181663    The specific motive is unknown; however, sourc...
# 181665    The specific motive is unknown; however, sourc...
# 181672    The specific motive is unknown; however, sourc...
# 181682    The specific motive is unknown; however, sourc...
# 181683    The specific motive is unknown; however, sourc...
# Name: Motive, Length: 35672, dtype: object

# %% [markdown]
# Terrorist Attack in india

# %%
attack_india=df[df['Country']== 'India']

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation= 45)
sns.countplot(x ='Year', data = attack_india)
plt.title('No of Attack in India')
# Out:
# Text(0.5, 1.0, 'No of Attack in India')

# %% [markdown]
# After 2007 attacks are gradully increases.

# %%
indian_stat=attack_india[attack_india['State'].isin(attack_india['State'].value_counts()[1:7].index)]
pd.crosstab(indian_stat.Year,indian_stat.State).plot(color=sns.color_palette('rainbow'))
fig=plt.gcf()
fig.set_size_inches(20,7)
plt.ylabel('No of Attacks')
# Out:
# Text(0, 0.5, 'No of Attacks')

# %% [markdown]
# 1. In Punjab State after 1981 attack increases till 1994.
# 2. In Punjab the number of attacks gradually reduced to 0 after the year 1994.
# 3. Assam has somewhat growth in attacks year 1981 to 2014.
# 4. After 2014 attacks decrease.
# 5. Bihar, Chharttisgarh, Jharkhand, Manipur for these states, attack increase after 2008.

# %% [markdown]
# 8) who are main targets of attacks?

# %%
df['Target_type'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target_type, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation = 90)
sns.barplot(df['Target_type'].value_counts().index,df['Target_type'].value_counts().values)
plt.title('main traget')
plt.xlabel('target')
plt.ylabel('frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'frequency')

# %% [markdown]
# Private Citizens & Property, Military, Police, Government (General), Business these are majour targets for terrorist groups.

# %% [markdown]
# 9)active groups

# %%
top_groups=df[df['Group'].isin(df['Group'].value_counts()[1:12].index)]
pd.crosstab(top_groups.Year,top_groups.Group).plot(color=sns.color_palette('rainbow'))
fig=plt.gcf()
fig.set_size_inches(20,7)

# %% [markdown]
# 1. Islamic State of iraq and the Leavant (ISIL) this group has no activites 1070 to 2011 but after 2011 this group is active.
# 2. Taliban is continously active and  highest number of terrorist activitiies.

# %% [markdown]
# Attacks in India vs Pakistan

# %%
#India
country_india= df[df['Year'] & (df['Country']== 'India')]
year_counts_for_india=pd.DataFrame(country_india['Year'].value_counts())
India_plot =year_counts_for_india.reset_index()
India_plot.head()
India_plot.rename(columns= {'index': 'year','Year':'toatl_incedent'}, inplace = True)
India_plot.head()

#Pakistan
country_pakistan= df[df['Year'] & (df['Country']== 'Pakistan')] 
year_counts_for_pakistan=pd.DataFrame(country_pakistan['Year'].value_counts())
Pakistan_plot =year_counts_for_pakistan.reset_index()
Pakistan_plot.head()
Pakistan_plot.rename(columns= {'index': 'year','Year':'toatl_incedent'}, inplace = True)
Pakistan_plot.head()

plt.figure(figsize=(20,8))
plt.xticks(rotation = 45)
sns.lineplot(x= 'year', y= 'toatl_incedent' , data = India_plot)
sns.lineplot(x= 'year', y= 'toatl_incedent' , data = Pakistan_plot)
plt.title('Number of attacks in India Vs Pakistan')
plt.legend(labels=["India","Pakistan"])

# %% [markdown]
# As compared to India, Pakistan has more terrorist attacks.

# %% [markdown]
# Iraq Vs Afghanistan

# %%
#Iraq
country_Iraq= df[df['Year'] & (df['Country']== 'Iraq')]
year_counts_for_Iraq=pd.DataFrame(country_Iraq['Year'].value_counts())
Iraq_plot =year_counts_for_Iraq.reset_index()
Iraq_plot.head()
Iraq_plot.rename(columns= {'index': 'year','Year':'toatl_incedent'}, inplace = True)
Iraq_plot.head()

#Afghanistan
country_Afghanistan= df[df['Year'] & (df['Country']== 'Afghanistan')] 
year_counts_for_Afghanistan=pd.DataFrame(country_Afghanistan['Year'].value_counts())
Afghanistan_plot =year_counts_for_Afghanistan.reset_index()
Afghanistan_plot.head()
Afghanistan_plot.rename(columns= {'index': 'year','Year':'toatl_incedent'}, inplace = True)
Afghanistan_plot.head()

plt.figure(figsize=(20,8))
plt.xticks(rotation = 45)
sns.lineplot(x= 'year', y= 'toatl_incedent' , data = Iraq_plot)
sns.lineplot(x= 'year', y= 'toatl_incedent' , data = Afghanistan_plot)
plt.title('Number of attacks in Iraq Vs Afghanistan')
plt.legend(labels=["Iraq","Afghanistan"])

# %% [markdown]
# For this case till 2001 Iraq and Afghanistan approximatly 0 attcaks but after 2002 Iraq has more attacks as compare to Afghanistan.

# %% [markdown]
# **Conlusion**

# %% [markdown]
# *  **Strong security should be given for the countries Iraq,Pakistan,Afghanistan and India and also for middle East Regions and cities like Bhagdad,Karachi lima and many others.**
#
# *   **Safety measures have to take regarding explosive devices as bombing explosions are the most weapons used by terrorsits.**
#
#
# *   **Strong security should be given to Private citizens and Property ,Military,Police etc as they are main target in terrorism.**
